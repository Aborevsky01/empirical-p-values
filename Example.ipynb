# %%
from launch import launch_binary_run, launch_multi_run

# %%
launch_multi_run(n_epochs=2)
# Out:
# Stage 1. Preparing launch.
# 	 Dataset was downloaded.
# 	 Data was acquired.
#
# 	 statistical data:
# 		 train num:    60000
# 		 train shape:  torch.Size([60000, 784])
# 		 test num:     10000
# 		 test shape:   torch.Size([10000, 784])
# Stage 2. Training model.
#   0%|          | 0/2 [00:00<?, ?it/s]
# Stage 3. Starting inference.
# 	 Model output was collected.
# 	 Scores were split by positive & negative.
# Stage 4. Creating graphs
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/andreyborevskiy/Downloads/EPV/stats.py:11: RuntimeWarning: invalid value encountered in double_scalars
#   with np.errstate(divide='ignore'): return y * np.log(y/mu) + (1-y) * np.log((1-y)/(1-mu))

# %%
launch_binary_run(n_epochs=3)
# Out:
# Stage 1. Preparing launch.
# 	 Dataset was downloaded.
# 	 Data was acquired.
#
# 	 statistical data:
# 		 train num:    60000
# 		 train shape:  torch.Size([60000, 784])
# 		 test num:     10000
# 		 test shape:   torch.Size([10000, 784])
# Stage 2. Training model.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Stage 3. Starting inference.
# 	 Model output was collected.
# 	 Local minima of kde was found.
# 	 Scores were split by positive & negative.
# 	 Statistical adjustment was accomplished.
# Stage 4. Creating graphs
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/andreyborevskiy/Downloads/EPV/stats.py:11: RuntimeWarning: invalid value encountered in double_scalars
#   with np.errstate(divide='ignore'): return y * np.log(y/mu) + (1-y) * np.log((1-y)/(1-mu))
# /usr/local/lib/python3.9/site-packages/scipy/stats/_discrete_distns.py:71: RuntimeWarning: divide by zero encountered in _binom_cdf
#   return _boost._binom_cdf(k, n, p)

# %%
launch_binary_run(test_mode='balanced', n_epochs=3)
# Out:
# Stage 1. Preparing launch.
# 	 Dataset was downloaded.
# 	 Data was acquired.
#
# 	 statistical data:
# 		 train num:    60000
# 		 train shape:  torch.Size([60000, 784])
# 		 test num:     10000
# 		 test shape:   torch.Size([2064, 784])
# Stage 2. Training model.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Stage 3. Starting inference.
# 	 Model output was collected.
# 	 Local minima of kde was found.
# 	 Scores were split by positive & negative.
# 	 Statistical adjustment was accomplished.
# Stage 4. Creating graphs
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/andreyborevskiy/Downloads/EPV/stats.py:11: RuntimeWarning: invalid value encountered in double_scalars
#   with np.errstate(divide='ignore'): return y * np.log(y/mu) + (1-y) * np.log((1-y)/(1-mu))

# %%
launch_binary_run(test_mode='shifted', n_epochs=2)
# Out:
# Stage 1. Preparing launch.
# 	 Dataset was downloaded.
# 	 Data was acquired.
#
# 	 statistical data:
# 		 train num:    60000
# 		 train shape:  torch.Size([60000, 784])
# 		 test num:     10000
# 		 test shape:   torch.Size([10000, 784])
# Stage 2. Training model.
#   0%|          | 0/2 [00:00<?, ?it/s]
